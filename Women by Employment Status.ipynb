# %%
import pandas as pd

# %%
data = pd.read_csv('ILOSTAT_.csv')

# %%
data
# Out:
#       collection   collection.label ref_area ref_area.label   source  \
# 0             YI  Yearly indicators      ABW          Aruba   BA:829
# 1             YI  Yearly indicators      ABW          Aruba   BA:829
# 2             YI  Yearly indicators      ABW          Aruba   BA:829
# 3             YI  Yearly indicators      ABW          Aruba   BA:829
# 4             YI  Yearly indicators      ABW          Aruba   BA:829
# 5             YI  Yearly indicators      ABW          Aruba   BA:829
# 6             YI  Yearly indicators      ABW          Aruba   BA:829
# 7             YI  Yearly indicators      ABW          Aruba   BA:829
# 8             YI  Yearly indicators      ABW          Aruba   BA:829
# 9             YI  Yearly indicators      ABW          Aruba   BA:829
# 10            YI  Yearly indicators      ABW          Aruba   BA:829
# 11            YI  Yearly indicators      ABW          Aruba   BA:829
# 12            YI  Yearly indicators      ABW          Aruba   BA:829
# ...

# %%
data.head(5)
# Out:
#   collection   collection.label ref_area ref_area.label  source  \
# 0         YI  Yearly indicators      ABW          Aruba  BA:829
# 1         YI  Yearly indicators      ABW          Aruba  BA:829
# 2         YI  Yearly indicators      ABW          Aruba  BA:829
# 3         YI  Yearly indicators      ABW          Aruba  BA:829
# 4         YI  Yearly indicators      ABW          Aruba  BA:829
#
#                       source.label            indicator  \
# 0  ABW - LFS - Labour force survey  EMP_TEMP_SEX_OCU_NB
# 1  ABW - LFS - Labour force survey  EMP_TEMP_SEX_OCU_NB
# 2  ABW - LFS - Labour force survey  EMP_TEMP_SEX_OCU_NB
# 3  ABW - LFS - Labour force survey  EMP_TEMP_SEX_OCU_NB
# 4  ABW - LFS - Labour force survey  EMP_TEMP_SEX_OCU_NB
#
#                                 indicator.label    sex   sex.label  ...  \
# 0  Employment by sex and occupation (thousands)  SEX_T  Sex: Total  ...
# 1  Employment by sex and occupation (thousands)  SEX_T  Sex: Total  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59845 entries, 0 to 59844
# Data columns (total 31 columns):
# collection              59845 non-null object
# collection.label        59845 non-null object
# ref_area                59845 non-null object
# ref_area.label          59845 non-null object
# source                  59845 non-null object
# source.label            59845 non-null object
# indicator               59845 non-null object
# indicator.label         59845 non-null object
# sex                     59845 non-null object
# sex.label               59845 non-null object
# classif1                59845 non-null object
# classif1.label          59845 non-null object
# classif2                0 non-null float64
# classif2.label          0 non-null float64
# classif3                0 non-null float64
# classif3.label          0 non-null float64
# classif4                0 non-null float64
# classif4.label          0 non-null float64
# ...
